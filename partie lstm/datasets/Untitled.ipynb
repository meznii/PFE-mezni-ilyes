# %%
import pandas as pd

# %%
data = pd.read_csv('dataset_final.csv', sep=',')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=74100, step=1)

# %%
d = data[['id_device','date', 'en_L1','cons_en_L1', 'en_L2', 'cons_en_L2', 'en_L3','cons_en_L3',  'hour', 'day','month', 'year', 'cons_glbal']]

# %%
# d['id_device'].rename('num_device')
d.rename(columns = {'id_device':'num_device'}, inplace = True)
# Out:
# C:\Users\21625\Miniconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
d
# Out:
#        num_device                 date         en_L1   cons_en_L1  \
# 0              34  2019-07-16 09:00:00  8.068350e+02   806.834961
# 1              34  2019-07-16 10:00:00  2.289109e+03  1482.274170
# 2              34  2019-07-16 11:00:00  3.494929e+03  1205.819580
# 3              34  2019-07-16 12:00:00  4.859251e+03  1364.322754
# 4              34  2019-07-16 13:00:00  6.098753e+03  1239.501465
# ...           ...                  ...           ...          ...
# 74095         253  2021-03-25 02:00:00  9.906793e+07  5959.625000
# 74096         253  2021-03-25 03:00:00  9.907422e+07  6293.125000
# 74097         253  2021-03-25 04:00:00  9.908019e+07  5970.000000
# 74098         253  2021-03-25 05:00:00  9.908592e+07  5731.625000
# 74099         253  2021-03-25 06:00:00  9.908808e+07  2157.125000
#
#               en_L2   cons_en_L2         en_L3   cons_en_L3  hour       day  \
# 0      2.069453e+03  2069.452637  1.355756e+02   135.575562     9   Tuesday
# ...

# %%
# d.to_csv('pfe_archive_energie.csv')

# %%
data = d[:3]
data
# Out:
#    num_device                 date        en_L1   cons_en_L1        en_L2  \
# 0          34  2019-07-16 09:00:00   806.834961   806.834961  2069.452637
# 1          34  2019-07-16 10:00:00  2289.109131  1482.274170  5071.029297
# 2          34  2019-07-16 11:00:00  3494.928711  1205.819580  7951.330078
#
#     cons_en_L2        en_L3   cons_en_L3  hour      day  month  year  \
# 0  2069.452637   135.575562   135.575562     9  Tuesday      7  2019
# 1  3001.576660  1358.957397  1223.381836    10  Tuesday      7  2019
# 2  2880.300781  2303.930176   944.972778    11  Tuesday      7  2019
#
#     cons_glbal
# 0  3011.863159
# 1  5707.232666
# 2  5031.093140

# %%
d.groupby(['hour','day','month'])['cons_glbal'].min()
# Out:
# hour  day        month
# 0     Friday     1        3390.582031
#                  2        2911.968750
#                  3        3078.921875
#                  4        3080.742188
#                  5        3413.203125
#                              ...
# 23    Wednesday  8        3365.125000
#                  9         529.500000
#                  10        542.968750
#                  11       2927.375000
#                  12       3189.421875
# Name: cons_glbal, Length: 2016, dtype: float64

# %%
d = d[d['date']>'2020-01-1 06:00:00']
# d34 = d34[12000:]
# d34.to_csv('device34.csv')

# %%
d34 = d34[d34['num_device']==34]
d34.to_csv('device34.csv')

# %%
d192 = d[d['num_device']==192]
d192.to_csv('device192.csv')
